# %% [markdown]
# <a href="https://colab.research.google.com/github/VitikaJain25/HealthCareNLPCourse/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas - Reading datasets of various forms into dataframes
import pandas as pd
# Numerical Python - Mathematical array operations
import numpy as np

# %%
print (pd)
# Out:
# <module 'pandas' from '/usr/local/lib/python3.7/dist-packages/pandas/__init__.py'>

# %% [markdown]
# ### Pandas Series
#
#
#
# *   Create series type of data using various data structures collection - array, list, tuples, dict etc.

# %%
# 1D representation of data - Series
# Series does not provide many inbuilt functions.
data = pd.Series([10, 20, 30, 40, 50, 60, 70])
print (data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
data.values
# Out:
# array([10, 20, 30, 40, 50, 60, 70])

# %%
# Collection Of Series
data_series = {'Column1' : pd.Series([100, 200, 300, 400, 500, 600, 700]),
               'Column2' : pd.Series([10, 20, 30, 40, 50, 60, 70])
}
print(data_series)
# Out:
# {'Column1': 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# 5    600
# 6    700
# dtype: int64, 'Column2': 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64}

# %%
# The above is bad data representation.
# Typecast series to DataFrames.
pd.DataFrame(data_series)
# Out:
#    Column1  Column2
# 0      100       10
# 1      200       20
# 2      300       30
# 3      400       40
# 4      500       50
# 5      600       60
# 6      700       70

# %% [markdown]
# ### DataFrame
#
#
# *   Dataframe is data structure represented in 2 - Dimentional table much of like spreadsheet.

# %%
# Seperator - ',' (Delimiter)
movies_df = pd.read_csv("https://raw.githubusercontent.com/VitikaJain25/MLDataSets/main/movies.csv")
# movies_df = pd.read_csv("https://raw.githubusercontent.com/VitikaJain25/MLDataSets/main/movies.csv", sep ',')
display(movies_df)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
# head() - Displays first five rows from dataframe. - By Default top 5 rows
# tail() - Displays last 5 row from dataframe. - By Default bottom 5 rows
movies_df.head()
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %%
# display top 10 rows instead of 5.
movies_df.head(10)
# Out:
#                                  Film      Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno    Romance  The Weinstein Company
# 1                     Youth in Revolt     Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger     Comedy            Independent
# 3                        When in Rome     Comedy                 Disney
# 4               What Happens in Vegas     Comedy                    Fox
# 5                 Water For Elephants      Drama       20th Century Fox
# 6                              WALL-E  Animation                 Disney
# 7                            Waitress    Romance            Independent
# 8                 Waiting For Forever    Romance            Independent
# 9                     Valentine's Day     Comedy           Warner Bros.
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# ...

# %%
# display bottom 10 rows instead of 5.
movies_df.tail(10)
# Out:
#                     Film    Genre   Lead Studio  Audience score %  \
# 67      Four Christmases   Comedy  Warner Bros.                52
# 68             Fireproof    Drama   Independent                51
# 69             Enchanted   Comedy        Disney                80
# 70             Dear John    Drama          Sony                66
# 71             Beginners   Comedy   Independent                80
# 72   Across the Universe  romance   Independent                84
# 73         A Serious Man    Drama     Universal                64
# 74    A Dangerous Method    Drama   Independent                89
# 75            27 Dresses   Comedy           Fox                71
# 76  (500) Days of Summer   comedy           Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 67       2.022925                 26        $161.83   2008
# 68      66.934000                 40         $33.47   2008
# 69       4.005737                 93        $340.49   2007
# ...

# %%
# display top 5 and bottom 5 rows.
display(movies_df)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
# Read an Excel file
stock_data = pd.read_excel("https://github.com/VitikaJain25/MLDataSets/blob/main/data_akbilgic.xlsx?raw=true")
stock_data
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#               Unnamed: 0  TL BASED USD BASED    imkb_x Unnamed: 4 Unnamed: 5  \
# 0                   date       ISE       ISE        SP        DAX       FTSE
# 1    2009-01-05 00:00:00  0.035754  0.038376 -0.004679   0.002193   0.003894
# 2    2009-01-06 00:00:00  0.025426  0.031813  0.007787   0.008455   0.012866
# 3    2009-01-07 00:00:00 -0.028862 -0.026353 -0.030469  -0.017833  -0.028735
# 4    2009-01-08 00:00:00 -0.062208 -0.084716  0.003391  -0.011726  -0.000466
# ..                   ...       ...       ...       ...        ...        ...
# 532  2011-02-16 00:00:00  0.008599    0.0134  0.006238   0.001925   0.007952
# 533  2011-02-17 00:00:00   0.00931  0.015977  0.003071  -0.001186   0.000345
# 534  2011-02-18 00:00:00  0.000191 -0.001653  0.001923   0.002872  -0.000723
# ...

# %%
# Header - by default as 0, which means the first row is considered as data.
stock_data = pd.read_excel("https://github.com/VitikaJain25/MLDataSets/blob/main/data_akbilgic.xlsx?raw=true", header = 1)
stock_data
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#           date       ISE     ISE.1        SP       DAX      FTSE    NIKKEI  \
# 0   2009-01-05  0.035754  0.038376 -0.004679  0.002193  0.003894  0.000000
# 1   2009-01-06  0.025426  0.031813  0.007787  0.008455  0.012866  0.004162
# 2   2009-01-07 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 3   2009-01-08 -0.062208 -0.084716  0.003391 -0.011726 -0.000466 -0.040061
# 4   2009-01-09  0.009860  0.009658 -0.021533 -0.019873 -0.012710 -0.004474
# ..         ...       ...       ...       ...       ...       ...       ...
# 531 2011-02-16  0.008599  0.013400  0.006238  0.001925  0.007952  0.005717
# 532 2011-02-17  0.009310  0.015977  0.003071 -0.001186  0.000345  0.002620
# 533 2011-02-18  0.000191 -0.001653  0.001923  0.002872 -0.000723  0.000568
# ...

# %%
# Shape displays (rows, columns)
stock_data.shape
# Out:
# (536, 10)

# %%
# Name of columns
movies_df.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability',
#        'Rotten Tomatoes %', 'Worldwide Gross', 'Year'],
#       dtype='object')

# %%
# Number of columns.
len(movies_df.columns)
# Out:
# 8

# %% [markdown]
# ### Data Manipulation

# %%
#info() - Displays detailed info about the dataset
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               77 non-null     object
#  1   Genre              77 non-null     object
#  2   Lead Studio        77 non-null     object
#  3   Audience score %   77 non-null     int64
#  4   Profitability      77 non-null     float64
#  5   Rotten Tomatoes %  77 non-null     int64
#  6   Worldwide Gross    77 non-null     object
#  7   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
# Sorting And unique Values
# Default is Ascending order
movies_df['Profitability'].sort_values()

# Descending Order
#movies_df['Profitability'].sort_values(ascending = False)
# Out:
# 3      0.000000
# 33     0.000000
# 57     0.000000
# 8      0.005000
# 42     0.252895
#         ...
# 12    10.180027
# 7     11.089742
# 14    14.196400
# 60    22.913136
# 68    66.934000
# Name: Profitability, Length: 77, dtype: float64

# %%
# Descending Order
movies_df.sort_values(by = 'Audience score %', ascending = False)
# Out:
#                                   Film      Genre            Lead Studio  \
# 74                  A Dangerous Method      Drama            Independent
# 6                               WALL-E  Animation                 Disney
# 22                             Tangled  Animation                 Disney
# 39                My Week with Marilyn      Drama  The Weinstein Company
# 72                 Across the Universe    romance            Independent
# ..                                 ...        ...                    ...
# 55                             Killers     Action              Lionsgate
# 3                         When in Rome     Comedy                 Disney
# 18                  The Heartbreak Kid     Comedy              Paramount
# 48                        Love Happens      Drama              Universal
# 2   You Will Meet a Tall Dark Stranger     Comedy            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
movies_df[movies_df.duplicated()]
# Out:
#                  Film      Genre Lead Studio  Audience score %  Profitability  \
# 46         Mamma Mia!     Comedy   Universal                76       9.234454
# 65  Gnomeo and Juliet  Animation      Disney                52       5.387972
#
#     Rotten Tomatoes % Worldwide Gross  Year
# 46                 53        $609.47   2008
# 65                 56        $193.97   2011

# %%
movies_df.duplicated().sum()
# Out:
# 2

# %%
# Checking the duplicates
movies_df[movies_df.Film == 'Mamma Mia!']
# Out:
#           Film   Genre Lead Studio  Audience score %  Profitability  \
# 45  Mamma Mia!  Comedy   Universal                76       9.234454
# 46  Mamma Mia!  Comedy   Universal                76       9.234454
#
#     Rotten Tomatoes % Worldwide Gross  Year
# 45                 53        $609.47   2008
# 46                 53        $609.47   2008

# %%
# Checking the duplicates
movies_df[movies_df.Film == 'Gnomeo and Juliet']
# Out:
#                  Film      Genre Lead Studio  Audience score %  Profitability  \
# 64  Gnomeo and Juliet  Animation      Disney                52       5.387972
# 65  Gnomeo and Juliet  Animation      Disney                52       5.387972
#
#     Rotten Tomatoes % Worldwide Gross  Year
# 64                 56        $193.97   2011
# 65                 56        $193.97   2011

# %%
# Checking indiex of duplicates
movies_df[40:70]
# Out:
#                                   Film      Genre       Lead Studio  \
# 40                    Music and Lyrics    Romance      Warner Bros.
# 41                         Monte Carlo    Romance  20th Century Fox
# 42      Miss Pettigrew Lives for a Day     Comedy       Independent
# 43                   Midnight in Paris    Romence              Sony
# 44                       Marley and Me     Comedy               Fox
# 45                          Mamma Mia!     Comedy         Universal
# 46                          Mamma Mia!     Comedy         Universal
# 47                       Made of Honor      Comdy              Sony
# 48                        Love Happens      Drama         Universal
# 49                  Love & Other Drugs     Comedy               Fox
# 50                  Life as We Know It     Comedy       Independent
# 51                      License to Wed     Comedy      Warner Bros.
# 52                   Letters to Juliet     Comedy            Summit
# ...

# %%
# Drop Duplicates - It drops whole duplicate rows and make sure the Dataframe is only having unique rows and columns.
movies_df.drop_duplicates(inplace = True)
movies_df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
# Checking indiex after removing duplicates.
movies_df[40:70]
# Out:
#                                   Film      Genre       Lead Studio  \
# 40                    Music and Lyrics    Romance      Warner Bros.
# 41                         Monte Carlo    Romance  20th Century Fox
# 42      Miss Pettigrew Lives for a Day     Comedy       Independent
# 43                   Midnight in Paris    Romence              Sony
# 44                       Marley and Me     Comedy               Fox
# 45                          Mamma Mia!     Comedy         Universal
# 47                       Made of Honor      Comdy              Sony
# 48                        Love Happens      Drama         Universal
# 49                  Love & Other Drugs     Comedy               Fox
# 50                  Life as We Know It     Comedy       Independent
# 51                      License to Wed     Comedy      Warner Bros.
# 52                   Letters to Juliet     Comedy            Summit
# 53                           Leap Year     Comedy         Universal
# ...

# %%
# ML algorithms gets bias while fitted to duplicate samples.

# %% [markdown]
# ### Drop Rows and Columns

# %%
# Rowwise Drop : (axis = 0 indicates row wise drop)
movies_df.drop([0, 2, 3, 4, 7, 8, 9], axis = 0)
# Out:
#                                    Film      Genre            Lead Studio  \
# 1                       Youth in Revolt     Comedy  The Weinstein Company
# 5                   Water For Elephants      Drama       20th Century Fox
# 6                                WALL-E  Animation                 Disney
# 10  Tyler Perry's Why Did I get Married    Romance            Independent
# 11              Twilight: Breaking Dawn    Romance            Independent
# ..                                  ...        ...                    ...
# 72                  Across the Universe    romance            Independent
# 73                        A Serious Man      Drama              Universal
# 74                   A Dangerous Method      Drama            Independent
# 75                           27 Dresses     Comedy                    Fox
# 76                 (500) Days of Summer     comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
# Dropping a column using column names (axis = 1 indicates column wise drop)
movies_df.drop(['Lead Studio', 'Audience score %', 'Rotten Tomatoes %'], axis = 1)
# Out:
#                                   Film    Genre  Profitability  \
# 0           Zack and Miri Make a Porno  Romance       1.747542
# 1                      Youth in Revolt   Comedy       1.090000
# 2   You Will Meet a Tall Dark Stranger   Comedy       1.211818
# 3                         When in Rome   Comedy       0.000000
# 4                What Happens in Vegas   Comedy       6.267647
# ..                                 ...      ...            ...
# 72                 Across the Universe  romance       0.652603
# 73                       A Serious Man    Drama       4.382857
# 74                  A Dangerous Method    Drama       0.448645
# 75                          27 Dresses   Comedy       5.343622
# 76                (500) Days of Summer   comedy       8.096000
#
#    Worldwide Gross  Year
# 0          $41.94   2008
# 1          $19.62   2010
# 2          $26.66   2010
# 3          $43.04   2010
# 4         $219.37   2008
# ..             ...   ...
# ...
